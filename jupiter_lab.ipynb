# %% [markdown]
# # Заголовок 1
# ## Заголовок 2
# ### Заголовок 3
#
# **Жирный текст**
# *Курсив*
# - список
# 1. нумерованный список
#
# `код внутри строки`
#
# [Ссылка](https://example.com)

# %%
# Проверка работы ячейки и вывод сообщения
print("JupyterLab успешно запущен!")
# Out:
# JupyterLab успешно запущен!
